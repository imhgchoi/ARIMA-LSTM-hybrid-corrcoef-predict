# %% [markdown]
# # Library Import

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import math
import os
import random

# %% [markdown]
# # Item Selection
#
# I selected all the assets that had data from 2008-01-01 among the S&P500 stock list.

# %%
path = 'C:/Users/Froilan/Desktop/myFiles/JupyterFiles/stock_correlation_prediction/stock_data'
stock08 = []
for file in os.listdir(path):
    file_path = path + '/' + file
    date = pd.read_csv(file_path)['Date']
    if len(date)>0 and pd.read_csv(file_path)['Date'][0] <= '2008-01-01' :
        stock08.append(file)
print(str(len(stock08))+" stocks selected")
print(stock08)
# Out:
# 446 stocks selected
# ['A.csv', 'AAL.csv', 'AAP.csv', 'AAPL.csv', 'ABC.csv', 'ABT.csv', 'ACN.csv', 'ADBE.csv', 'ADI.csv', 'ADM.csv', 'ADP.csv', 'ADS.csv', 'ADSK.csv', 'AEE.csv', 'AEP.csv', 'AES.csv', 'AET.csv', 'AFL.csv', 'AGN.csv', 'AIG.csv', 'AIV.csv', 'AIZ.csv', 'AJG.csv', 'AKAM.csv', 'ALB.csv', 'ALGN.csv', 'ALK.csv', 'ALL.csv', 'ALXN.csv', 'AMAT.csv', 'AMD.csv', 'AME.csv', 'AMG.csv', 'AMGN.csv', 'AMP.csv', 'AMT.csv', 'AMZN.csv', 'ANSS.csv', 'ANTM.csv', 'AON.csv', 'AOS.csv', 'APA.csv', 'APC.csv', 'APD.csv', 'APH.csv', 'ARE.csv', 'ARNC.csv', 'ATVI.csv', 'AVB.csv', 'AVY.csv', 'AXP.csv', 'AYI.csv', 'AZO.csv', 'BA.csv', 'BAC.csv', 'BAX.csv', 'BBT.csv', 'BBY.csv', 'BDX.csv', 'BEN.csv', 'BF.B.csv', 'BIIB.csv', 'BK.csv', 'BLK.csv', 'BLL.csv', 'BMY.csv', 'BRK.B.csv', 'BSX.csv', 'BWA.csv', 'BXP.csv', 'C.csv', 'CA.csv', 'CAG.csv', 'CAH.csv', 'CAT.csv', 'CB.csv', 'CBS.csv', 'CCI.csv', 'CCL.csv', 'CDNS.csv', 'CELG.csv', 'CERN.csv', 'CF.csv', 'CHD.csv', 'CHRW.csv', 'CI.csv', 'CINF.csv', 'CL.csv', 'CLX.csv', 'CMA.csv', 'CMCSA.csv', 'CME.csv', 'CMG.csv', 'CMI.csv', 'CMS.csv', 'CNC.csv', 'CNP.csv', 'COF.csv', 'COG.csv', 'COL.csv', 'COO.csv', 'COP.csv', 'COST.csv', 'CPB.csv', 'CRM.csv', 'CSCO.csv', 'CSX.csv', 'CTAS.csv', 'CTL.csv', 'CTSH.csv', 'CTXS.csv', 'CVS.csv', 'CVX.csv', 'CXO.csv', 'D.csv', 'DAL.csv', 'DE.csv', 'DFS.csv', 'DGX.csv', 'DHI.csv', 'DHR.csv', 'DIS.csv', 'DISCA.csv', 'DISH.csv', 'DLR.csv', 'DLTR.csv', 'DOV.csv', 'DRE.csv', 'DRI.csv', 'DTE.csv', 'DUK.csv', 'DVA.csv', 'DVN.csv', 'EA.csv', 'EBAY.csv', 'ECL.csv', 'ED.csv', 'EFX.csv', 'EIX.csv', 'EL.csv', 'EMN.csv', 'EMR.csv', 'EOG.csv', 'EQIX.csv', 'EQR.
'PCG.csv', 'PEG.csv', 'PEP.csv', 'PFE.csv', 'PFG.csv', 'PG.csv', 'PGR.csv', 'PH.csv', 'PHM.csv', 'PKG.csv', 'PKI.csv', 'PLD.csv', 'PNC.csv', 'PNR.csv', 'PNW.csv', 'PPL.csv', 'PRGO.csv', 'PRU.csv', 'PSA.csv', 'PVH.csv', 'PWR.csv', 'PX.csv', 'PXD.csv', 'QCOM.csv', 'RCL.csv', 'RE.csv', 'REG.csv', 'REGN.csv', 'RF.csv', 'RHI.csv', 'RHT.csv', 'RJF.csv', 'RL.csv', 'RMD.csv', 'ROK.csv', 'ROP.csv', 'ROST.csv', 'RRC.csv', 'RSG.csv', 'RTN.csv', 'SBAC.csv', 'SBUX.csv' ...

# %% [markdown]
# # Organize Data
#
# In order to keep concise and deal with missing data, I concatenated all the price data of the selected items above to a single dataframe

# %%
stock_price_dict = {}

for file in stock08 :
    path = "C:/Users/Froilan/Desktop/myFiles/JupyterFiles/stock_correlation_prediction/stock_data/" + file
    df = pd.read_csv(path)
    df = df[df.Date >= '2008-01-01']
    pd.to_datetime(df['Date'], format='%Y-%m-%d')
    df = df.set_index(pd.DatetimeIndex(df['Date']))
    stock_price_dict[file.split(".")[0]] = df['Adj. Close']

market_path = "C:/Users/Froilan/Desktop/myFiles/JupyterFiles/stock_correlation_prediction/SP500_index.csv"
df = pd.read_csv(market_path)
pd.to_datetime(df['Date'], format='%Y-%m-%d')
df = df.set_index(pd.DatetimeIndex(df['Date']))
stock_price_dict['SP500'] = df['Adj Close']
    
stock_price_df = pd.DataFrame(stock_price_dict)

# %%
print(stock_price_df.head())
# Out:
#                     A        AAL        AAP       AAPL        ABC        ABT  \
# Date
# 2008-01-02  24.765337  34.609917  36.353428  25.039656  19.399748  20.518491
# 2008-01-03  24.519730  33.050912  36.701586  25.051222  19.517323  20.393490
# 2008-01-04  23.721509  32.245426  34.496589  23.138934  19.073153  20.511138
# 2008-01-07  24.110386  31.777724  36.053626  22.829216  19.325720  21.139817
# 2008-01-08  24.076274  28.607747  34.196787  22.008012  19.878755  21.694967
#
#                   ACN   ADBE        ADI        ADM    ...            XEC  \
# Date                                                  ...
# 2008-01-02  29.385905  41.71  23.023535  35.939893    ...      40.892132
# 2008-01-03  28.880657  41.79  22.674809  36.313108    ...      40.911072
# 2008-01-04  28.448751  40.36  22.083490  36.408398    ...      39.689422
# 2008-01-07  27.682729  40.24  21.802992  36.416338    ...      39.755713
# 2008-01-08  27.682729  39.22  21.082796  35.749314    ...      40.087168
#
#                   XEL         XL       XLNX        XOM       XRAY        XRX  \
# Date
# 2008-01-02  14.938655  38.246913  16.502553  70.732584  41.359295  50.882074
# 2008-01-03  15.026252  38.666370  16.416602  70.974637  41.747157  50.496116
# 2008-01-04  14.857797  38.048624  15.908711  69.650907  40.943053  48.598491
# 2008-01-07  15.086897  39.261238  15.986848  69.000388  41.926897  48.566328
# 2008-01-08  14.931917  36.530950  15.393006  68.115380  42.153938  47.665760
#
#                   YUM        ZBH       ZION
# Date
# 2008-01-02  22.069409  62.908820  41.607762
# 2008-01-03  21.760624  62.975250  40.771748
# 2008-01-04  21.451839  63.108108  38.952729
# 2008-01-07  21.952887  65.157939  39.761182
# 2008-01-08  21.393577  63.819853  38.364764
#
# [5 rows x 447 columns]

# %% [markdown]
# # Dealing with Missing Data

# %%
NA_col = []
NA_ratio = []
for col in stock_price_df.columns :
    na_index = np.where(stock_price_df[col].isnull())[0]
    NA_col.append(col)
    NA_ratio.append(len(na_index)/stock_price_df.shape[0] * 100)
    print(col,na_index)
NA_df = pd.DataFrame({'tickers':NA_col,'NA_ratio':NA_ratio})
# Out:
# A [2338 2483]
# AAL [2338 2483]
# AAP [2338 2483]
# AAPL [2338 2417 2483]
# ABC [2338 2483]
# ABT [2338 2481 2483]
# ACN [2338 2483]
# ADBE [2338 2417 2483]
# ADI [2338 2483]
# ADM [2338 2483]
# ADP [2338 2483]
# ADS [2338 2483]
# ADSK [2338 2483]
# AEE [2338 2483]
# AEP [2338 2483]
# AES [2338 2483]
# AET [2338 2483]
# AFL [2338 2483]
# AGN [2338 2483]
# AIG [2338 2483]
# AIV [2338 2483]
# AIZ [2338 2483]
# AJG [2338 2483]
# AKAM [2338 2417 2483]
# ALB [2338 2483]
# ALGN [2338 2483]
# ALK [2338 2483]
# ALL [2338 2483]
# ALXN [2338 2483]
# AMAT [2338 2483]
# AMD [2338 2483]
# AME [2338 2483]
# AMG [2338 2483]
# AMGN [2338 2483]
# AMP [2338 2483]
# AMT [2338 2483]
# AMZN [2338 2417 2483]
# ANSS [2338 2483]
# ANTM [2338 2483]
# AON [2338 2483]
# AOS [2338 2483]
# APA [2338 2483]
# APC [2338 2483]
# APD [2338 2483]
# APH [2338 2483]
# ARE [2338 2483]
# ARNC [2338 2483]
# ATVI [2338 2417 2483]
# AVB [2338 2483]
# AVY [2338 2483]
# AXP [2338 2483]
# AYI [2338 2483]
# AZO [2338 2483]
# BA [2338 2483]
# BAC [2338 2483]
# BAX [2338 2483]
# BBT [2338 2483]
# BBY [2338 2483]
# BDX [2338 2483]
# BEN [2338 2483]
# BF [2338 2483]
# BIIB [2338 2483]
# BK [2338 2483]
# BLK [2338 2483]
# BLL [2338 2483]
# BMY [2338 2483]
# BRK [2338 2483]
# BSX [2338 2483]
# BWA [2338 2483]
# BXP [2338 2483]
# C [2338 2483]
# CA [2338 2483]
# CAG [2338 2483]
# CAH [2338 2483]
# CAT [2338 2483]
# CB [2338 2483]
# CBS [2338 2483]
# CCI [2338 2483]
# CCL [2338 2483]
# CDNS [2338 2483]
# CELG [2338 2417 2483]
# CERN [2338 2483]
# CF [2338 2483]
# CHD [2338 2483]
# CHRW [2338 2483]
# CI [2338 2483]
# CINF [2338 2483]
# CL [2338 2483]
# CLX [2338 2483]
# CMA [2338 2483]
# CMCSA [2338 2417 2483]
# CME [2338 2483]
# CMG [2338 2483]
# CMI [2338 2483]
# CMS [2338 2483]
# CNC [2338 2483]
# CNP [2338 2483]
# COF [2338 2483]
# COG [2338 2483]
# COL [2338 2483]
# COO [2338 2483]
# COP [2338 2483]
# COST [2338 2417 2483]
# CPB [2338 2483]
# CRM [2338 2483]
# CSCO [2338 2483]
# CSX [2338 2483]
# SCHW [2338 2483]
# SEE [2338 2483]
# SHW [2338 2483]
# SIVB [2338 2483]
# SJM [2338 2483]
# SLB [2338 2483]
# SLG [2338 2483]
# SNA [2338 2483]
# SNPS [2338 2483]
# SO [2338 2483]
# SP500 [2338]
# SPG [2338 2483]
# SRCL [2338 2483]
# SRE [2338 2483]
# STI [2338 2483]
# STT [2338 2483]
# STX [2338 2483]
# STZ [2338 2483]
# SWK [2338 2483]
# SWKS [2338 2483]
# SYK [2338 2483]
# SYMC [2338 2483]
# SYY [2338 2483]
# T [2338 2483]
# TAP [2338 2483]
# TDG [2338 2483]
# TEL [2338 2483]
# TGT [2338 2483]
# TIF [2338 2483]
# TJX [2338 2483]
# TMK [2338 2483]
# TMO [2338 2483]
# TROW [2338 2483]
# TSCO [2338 2483]
# TSN [2338 2483]
# TSS [2338 2483]
# TTWO [2338 2483]
# TWX [2338 2483]
# TXN [2338 2483]
# TXT [2338 2483]
# UAA [2338 2483]
# UAL [2338 2483]
# UDR [2338 2483]
# UHS [2338 2483]
# ULTA [2338 2483]
# UNH [2338 2483]
# UNM [2338 2483]
# UNP [2338 2483]
# UPS [2338 2483]
# URI [2338 2483]
# USB [2338 2483]
# UTX [2338 2483]
# VAR [2338 2483]
# VFC [2338 2483]
# VIAB [2338 2483]
# VLO [2338 2483]
# VMC [2338 2483]
# VNO [2338 2483]
# VRSN [2338 2483]
# VRTX [2338 2483]
# VTR [2338 2483]
# VZ [2338 2483]
# WAT [2338 2483]
# WBA [2338 2483]
# WDC [2338 2483]
# WEC [2338 2483]
# WFC [2338 2483]
# WHR [2338 2483]
# WM [2338 2483]
# WMB [2338 2483]
# WMT [2338 2483]
# WU [2338 2483]
# WY [2338 2483]
# WYN [2338 2483]
# WYNN [2338 2483]
# XEC [2338 2483]
# XEL [2338 2483]
# XL [2338 2483]
# XLNX [2338 2483]
# XOM [2338 2483]
# XRAY [2338 2483]
# XRX [2338 2483]
# YUM [2338 2483]
# ZBH [2338 2483]
# ZION [2338 2483]

# %%
NA_df.plot.bar(rot=0, figsize=(18,4))
plt.tick_params(axis='x', which='both', bottom=True, top=False, labelbottom=False)
plt.xlabel('tickers')
plt.ylabel('NA ratio (%)')
plt.show()
plt.close()

# %% [markdown]
# Most of the dataset that has missing data has only one or two data points missing. It would be rational enough to impute the data points with the data from the day right before.
#
# However, one company has quite some missing data. 'MMM' is the only company that has high proportion of missing data. Leaving out this one company from the S&P 500 firms wouldn't be a big issue. So I'll drop the 'MMM' column the dataframe

# %%
stock_price_df = stock_price_df.drop(['MMM'], axis=1)

# %%
def impute_data(column_name):
    index = stock_price_df.index.values[0]
    price_na_index = np.where(stock_price_df[column_name].isnull())[0]
    for i in price_na_index :
        stock_price_df[column_name][i] = stock_price_df[column_name][i-1]

# %%
for item in stock_price_df.columns :
    impute_data(item)

# %%
# Final Check for NaN
for item in stock_price_df.columns :
    if stock_price_df[item].isnull().values.any() :
        print('stock price data of '+item+' still has NaN')
print("END OF CHECKING. NO NA REMAINING")
# Out:
# END OF CHECKING. NO NA REMAINING

# %%
stock_price_df.to_csv("C:/Users/Froilan/Desktop/myFiles/JupyterFiles/stock_correlation_prediction/stock08_price.csv",index_label='Date')

# %% [markdown]
# # Create Portfolio
#
# out of 505 companies, 150 firms are randomly selected for the portfolio.

# %%
df = pd.read_csv("C:/Users/Froilan/Desktop/myFiles/JupyterFiles/stock_correlation_prediction/stock08_price.csv")
universe = list(df.columns.values[1:])
universe.remove("SP500")
print(universe)
# Out:
# ['A', 'AAL', 'AAP', 'AAPL', 'ABC', 'ABT', 'ACN', 'ADBE', 'ADI', 'ADM', 'ADP', 'ADS', 'ADSK', 'AEE', 'AEP', 'AES', 'AET', 'AFL', 'AGN', 'AIG', 'AIV', 'AIZ', 'AJG', 'AKAM', 'ALB', 'ALGN', 'ALK', 'ALL', 'ALXN', 'AMAT', 'AMD', 'AME', 'AMG', 'AMGN', 'AMP', 'AMT', 'AMZN', 'ANSS', 'ANTM', 'AON', 'AOS', 'APA', 'APC', 'APD', 'APH', 'ARE', 'ARNC', 'ATVI', 'AVB', 'AVY', 'AXP', 'AYI', 'AZO', 'BA', 'BAC', 'BAX', 'BBT', 'BBY', 'BDX', 'BEN', 'BF', 'BIIB', 'BK', 'BLK', 'BLL', 'BMY', 'BRK', 'BSX', 'BWA', 'BXP', 'C', 'CA', 'CAG', 'CAH', 'CAT', 'CB', 'CBS', 'CCI', 'CCL', 'CDNS', 'CELG', 'CERN', 'CF', 'CHD', 'CHRW', 'CI', 'CINF', 'CL', 'CLX', 'CMA', 'CMCSA', 'CME', 'CMG', 'CMI', 'CMS', 'CNC', 'CNP', 'COF', 'COG', 'COL', 'COO', 'COP', 'COST', 'CPB', 'CRM', 'CSCO', 'CSX', 'CTAS', 'CTL', 'CTSH', 'CTXS', 'CVS', 'CVX', 'CXO', 'D', 'DAL', 'DE', 'DFS', 'DGX', 'DHI', 'DHR', 'DIS', 'DISCA', 'DISH', 'DLR', 'DLTR', 'DOV', 'DRE', 'DRI', 'DTE', 'DUK', 'DVA', 'DVN', 'EA', 'EBAY', 'ECL', 'ED', 'EFX', 'EIX', 'EL', 'EMN', 'EMR', 'EOG', 'EQIX', 'EQR', 'EQT', 'ES', 'ESRX', 'ESS', 'ETFC', 'ETN', 'ETR', 'EW', 'EXC', 'EXPD', 'EXPE', 'EXR', 'F', 'FAST', 'FCX', 'FDX', 'FE', 'FFIV', 'FIS', 'FISV', 'FITB', 'FL', 'FLIR', 'FLR', 'FLS', 'FMC', 'FOX', 'FOXA', 'FRT', 'FTI', 'GD', 'GE', 'GGP', 'GILD', 'GIS', 'GLW', 'GOOGL', 'GPC', 'GPN', 'GPS', 'GRMN', 'GS', 'GT', 'GWW', 'HAL', 'HAS', 'HBAN', 'HBI', 'HCP', 'HD', 'HES', 'HIG', 'HOG', 'HOLX', 'HON', 'HP', 'HPQ', 'HRB', 'HRL', 'HRS', 'HSIC', 'HST', 'HSY', 'HUM', 'IBM', 'ICE', 'IDXX', 'IFF', 'ILMN', 'INCY', 'INTC', 'INTU', 'IP', 'IPG', 'IPGP', 'IR', 'IRM', 'ISRG', 'IT', 'ITW', 'IVZ', 'JBHT', 'JCI', 'JEC', 'JNJ', 'JNPR', 'JPM', 'JWN', 'K', 'KEY', 'KIM', 'KLAC', 'KMB', 'KMX', 'KO', 'KR', 'KSS', 'KSU', 'L', 'LB', 'LEG', 'LEN', 'LH', 'LKQ', 'LLL', 'LLY', 'LMT', 'LNC', 'LNT', 'LOW', 'LRCX', 'LUK', 'LUV', 'M', 'MA', 'MAA', 'MAC', 'MAR', 'MAS', 'MAT', 'MCD', 'MCHP', 'MCK', 'MCO', 'MDLZ', 'MDT', 'MET', 'MGM', 'MHK', 'MKC', 'MLM', 'MMC', 'MNST', 'MO', 'MON', 'MOS', 'MRK', 'MRO', 'MS', 'MSCI', 'MSFT', 'MSI', 'MTB', 'MTD', 'MU', 'MYL', 'NBL', 'NDAQ', 'NEE', 'NEM', 'NFLX', 'NFX', 'NI', 'NKE', 'NKTR', 'NOC', 'NOV', 'NRG', 'NSC', 'NTAP', 'NTRS', 'NUE', 'NVDA', 'NWL', 'O', 'OKE', 'OMC', 'ORCL', 'ORLY', 'OXY', 'PAYX', 'PBCT', 'PCAR', 'PCG', 'PEG', 'PEP', 'PFE', 'PFG', 'PG', 'PGR', 'PH', 'PHM', 'PKG', 'PKI', 'PLD', 'PNC', 'PNR', 'PNW', 'PPL', 'PRGO', 'PRU', 'PSA', 'PVH', 'PWR', 'PX', 'PXD', 'QCOM', 'RCL', 'RE', 'REG', 'REGN', 'RF', 'RHI', 'RHT', 'RJF', 'RL', 'RMD', 'ROK', 'ROP', 'ROST', 'RRC', 'RSG', 'RTN', 'SBAC', 'SBUX', 'SCG', 'SCHW', 'SEE', 'SHW', 'SIVB', 'SJM', 'SLB', 'SLG', 'SNA', 'SNPS', 'SO', 'SPG', 'SRCL', 'SRE', 'STI', 'STT', 'STX', 'STZ', 'SWK', 'SWKS', 'SYK', 'SYMC', 'SYY', 'T', 'TAP', 'TDG', 'TEL', 'TGT', 'TIF', 'TJX', 'TMK', 'TMO', 'TROW', 'TSCO', 'TSN', 'TSS', 'TTWO', 'TWX', 'TXN', 'TXT', 'UAA', 'UAL', 'UDR', 'UHS', 'ULTA', 'UNH', 'UNM', 'UNP', 'UPS', 'URI', 'USB', 'UTX', 'VAR', 'VFC', 'VIAB', 'VLO', 'VMC', 'VNO', 'VRSN', 'VRTX', 'VTR', 'VZ', 'WAT', 'WBA', 'WDC', 'WEC', 'WFC', 'WHR', 'WM', 'WMB', 'WMT', 'WU', 'WY', 'WYN', 'WYNN', 'XEC', 'XEL', 'XL', 'XLNX', 'XOM', 'XRAY', 'XRX', 'YUM', 'ZBH', 'ZION']

# %%
random.shuffle(universe)
portfolio = universe[:150].copy()

print(portfolio)
# Out:
# ['CELG', 'PXD', 'WAT', 'LH', 'AMGN', 'AOS', 'EFX', 'CRM', 'NEM', 'JNPR', 'LB', 'CTAS', 'MAT', 'MDLZ', 'VLO', 'APH', 'ADM', 'MLM', 'BK', 'NOV', 'BDX', 'RRC', 'IVZ', 'ED', 'SBUX', 'GRMN', 'CI', 'ZION', 'COO', 'TIF', 'RHT', 'FDX', 'LLL', 'GLW', 'GPN', 'IPGP', 'GPC', 'HPQ', 'ADI', 'AMG', 'MTB', 'YUM', 'SYK', 'KMX', 'AME', 'AAP', 'DAL', 'A', 'MON', 'BRK', 'BMY', 'KMB', 'JPM', 'CCI', 'AET', 'DLTR', 'MGM', 'FL', 'HD', 'CLX', 'OKE', 'UPS', 'WMB', 'IFF', 'CMS', 'ARNC', 'VIAB', 'MMC', 'REG', 'ES', 'ITW', 'NDAQ', 'AIZ', 'VRTX', 'CTL', 'QCOM', 'MSI', 'NKTR', 'AMAT', 'BWA', 'ESRX', 'TXT', 'EXR', 'VNO', 'BBT', 'WDC', 'UAL', 'PVH', 'NOC', 'PCAR', 'NSC', 'UAA', 'FFIV', 'PHM', 'LUV', 'HUM', 'SPG', 'SJM', 'ABT', 'CMG', 'ALK', 'ULTA', 'TMK', 'TAP', 'SCG', 'CAT', 'TMO', 'AES', 'MRK', 'RMD', 'MKC', 'WU', 'ACN', 'HIG', 'TEL', 'DE', 'ATVI', 'O', 'UNM', 'VMC', 'ETFC', 'CMA', 'NRG', 'RHI', 'RE', 'FMC', 'MU', 'CB', 'LNT', 'GE', 'CBS', 'ALGN', 'SNA', 'LLY', 'LEN', 'MAA', 'OMC', 'F', 'APA', 'CDNS', 'SLG', 'HP', 'XLNX', 'SHW', 'AFL', 'STT', 'PAYX', 'AIG', 'FOX', 'MA']

# %%
#FOR LIST REUSE#FOR LIS 
portfolio = ['CELG', 'PXD', 'WAT', 'LH', 'AMGN', 'AOS', 'EFX', 'CRM', 'NEM', 'JNPR', 'LB', 'CTAS', 'MAT', 'MDLZ', 'VLO', 'APH', 'ADM', 'MLM', 'BK', 'NOV', 'BDX', 'RRC', 'IVZ', 'ED', 'SBUX', 'GRMN', 'CI', 'ZION', 'COO', 'TIF', 'RHT', 'FDX', 'LLL', 'GLW', 'GPN', 'IPGP', 'GPC', 'HPQ', 'ADI', 'AMG', 'MTB', 'YUM', 'SYK', 'KMX', 'AME', 'AAP', 'DAL', 'A', 'MON', 'BRK', 'BMY', 'KMB', 'JPM', 'CCI', 'AET', 'DLTR', 'MGM', 'FL', 'HD', 'CLX', 'OKE', 'UPS', 'WMB', 'IFF', 'CMS', 'ARNC', 'VIAB', 'MMC', 'REG', 'ES', 'ITW', 'NDAQ', 'AIZ', 'VRTX', 'CTL', 'QCOM', 'MSI', 'NKTR', 'AMAT', 'BWA', 'ESRX', 'TXT', 'EXR', 'VNO', 'BBT', 'WDC', 'UAL', 'PVH', 'NOC', 'PCAR', 'NSC', 'UAA', 'FFIV', 'PHM', 'LUV', 'HUM', 'SPG', 'SJM', 'ABT', 'CMG', 'ALK', 'ULTA', 'TMK', 'TAP', 'SCG', 'CAT', 'TMO', 'AES', 'MRK', 'RMD', 'MKC', 'WU', 'ACN', 'HIG', 'TEL', 'DE', 'ATVI', 'O', 'UNM', 'VMC', 'ETFC', 'CMA', 'NRG', 'RHI', 'RE', 'FMC', 'MU', 'CB', 'LNT', 'GE', 'CBS', 'ALGN', 'SNA', 'LLY', 'LEN', 'MAA', 'OMC', 'F', 'APA', 'CDNS', 'SLG', 'HP', 'XLNX', 'SHW', 'AFL', 'STT', 'PAYX', 'AIG', 'FOX', 'MA']

# %% [markdown]
# # Prepare the Data

# %%
def rolling_corr(item1,item2) :
    #import data
    stock_price_df = pd.read_csv("C:/Users/Froilan/Desktop/myFiles/JupyterFiles/stock_correlation_prediction/stock08_price.csv")
    pd.to_datetime(stock_price_df['Date'], format='%Y-%m-%d')
    stock_price_df = stock_price_df.set_index(pd.DatetimeIndex(stock_price_df['Date']))
    
    #calculate
    df_pair = pd.concat([stock_price_df[item1], stock_price_df[item2]], axis=1)
    df_pair.columns = [item1,item2]
    df_corr = df_pair[item1].rolling(window=100).corr(df_pair[item2])
    return df_corr

# %%
index_list = []
for _ in range(100):
    indices = []
    for k in range(_, len(corr_series),100):
        indices.append(k)
    index_list.append(indices)
    
data_matrix = []
count = 0
for i in range(150):
    for j in range(149-i):
        a = portfolio[i]
        b = portfolio[149-j]
        file_name = a + '_' + b
            
        corr_series = rolling_corr(a, b)[99:]
        for _ in range(100):
            corr_strided = list(corr_series[index_list[_]][:24]).copy()
            data_matrix.append(corr_strided)
            count+=1
            if count % 1000 == 0 :
                print(str(count)+' items preprocessed')
                
data_matrix = np.transpose(data_matrix)
data_dictionary = {}
for i in range(len(data_matrix)):
    data_dictionary[str(i)] = data_matrix[i]
data_df = pd.DataFrame(data_dictionary)
data_df.to_csv('C:/Users/Froilan/Desktop/myFiles/JupyterFiles/stock_correlation_prediction/dataset.csv')
# Out:
# 1000 items preprocessed
# 2000 items preprocessed
# 3000 items preprocessed
# 4000 items preprocessed
# 5000 items preprocessed
# 6000 items preprocessed
# 7000 items preprocessed
# 8000 items preprocessed
# 9000 items preprocessed
# 10000 items preprocessed
# 11000 items preprocessed
# 12000 items preprocessed
# 13000 items preprocessed
# 14000 items preprocessed
# 15000 items preprocessed
# 16000 items preprocessed
# 17000 items preprocessed
# 18000 items preprocessed
# 19000 items preprocessed
# 20000 items preprocessed
# 21000 items preprocessed
# 22000 items preprocessed
# 23000 items preprocessed
# 24000 items preprocessed
# 25000 items preprocessed
# 26000 items preprocessed
# 27000 items preprocessed
# 28000 items preprocessed
# 29000 items preprocessed
# 30000 items preprocessed
# 31000 items preprocessed
# 32000 items preprocessed
# 33000 items preprocessed
# 34000 items preprocessed
# 35000 items preprocessed
# 36000 items preprocessed
# 37000 items preprocessed
# 38000 items preprocessed
# 39000 items preprocessed
# 40000 items preprocessed
# 41000 items preprocessed
# 42000 items preprocessed
# 43000 items preprocessed
# 44000 items preprocessed
# 45000 items preprocessed
# 46000 items preprocessed
# 47000 items preprocessed
# 48000 items preprocessed
# 49000 items preprocessed
# 50000 items preprocessed
# 51000 items preprocessed
# 52000 items preprocessed
# 53000 items preprocessed
# 54000 items preprocessed
# 55000 items preprocessed
# 56000 items preprocessed
# 57000 items preprocessed
# 58000 items preprocessed
# 59000 items preprocessed
# 60000 items preprocessed
# 61000 items preprocessed
# 62000 items preprocessed
# 63000 items preprocessed
# 64000 items preprocessed
# 65000 items preprocessed
# 66000 items preprocessed
# 67000 items preprocessed
# 68000 items preprocessed
# 69000 items preprocessed
# 70000 items preprocessed
# 71000 items preprocessed
# 72000 items preprocessed
# 73000 items preprocessed
# 74000 items preprocessed
# 75000 items preprocessed
# 76000 items preprocessed
# 77000 items preprocessed
# 78000 items preprocessed
# 79000 items preprocessed
# 80000 items preprocessed
# 81000 items preprocessed
# 82000 items preprocessed
# 83000 items preprocessed
# 84000 items preprocessed
# 85000 items preprocessed
# 86000 items preprocessed
# 87000 items preprocessed
# 88000 items preprocessed
# 89000 items preprocessed
# 90000 items preprocessed
# 91000 items preprocessed
# 92000 items preprocessed
# 93000 items preprocessed
# 94000 items preprocessed
# 95000 items preprocessed
# 96000 items preprocessed
# 97000 items preprocessed
# 98000 items preprocessed
# 99000 items preprocessed
# 100000 items preprocessed
# 101000 items preprocessed
# 102000 items preprocessed
# 103000 items preprocessed
# 104000 items preprocessed
# 105000 items preprocessed
# 106000 items preprocessed
# 107000 items preprocessed
# 108000 items preprocessed
# 109000 items preprocessed
# 110000 items preprocessed
# 111000 items preprocessed
# 112000 items preprocessed
# 113000 items preprocessed
# 114000 items preprocessed
# 115000 items preprocessed
# 116000 items preprocessed
# 117000 items preprocessed
# 118000 items preprocessed
# 119000 items preprocessed
# 120000 items preprocessed
# 121000 items preprocessed
# 122000 items preprocessed
# 123000 items preprocessed
# 124000 items preprocessed
# 125000 items preprocessed
# 126000 items preprocessed
# 127000 items preprocessed
# 128000 items preprocessed
# 129000 items preprocessed
# 130000 items preprocessed
# 131000 items preprocessed
# 132000 items preprocessed
# 133000 items preprocessed
# 134000 items preprocessed
# 135000 items preprocessed
# 136000 items preprocessed
# 137000 items preprocessed
# 138000 items preprocessed
# 139000 items preprocessed
# 140000 items preprocessed
# 141000 items preprocessed
# 142000 items preprocessed
# 143000 items preprocessed
# 144000 items preprocessed
# 145000 items preprocessed
# 146000 items preprocessed
# 147000 items preprocessed
# 148000 items preprocessed
# 149000 items preprocessed
# 150000 items preprocessed
# 151000 items preprocessed
# 152000 items preprocessed
# 153000 items preprocessed
# 154000 items preprocessed
# 155000 items preprocessed
# 156000 items preprocessed
# 157000 items preprocessed
# 158000 items preprocessed
# 159000 items preprocessed
# 160000 items preprocessed
# 161000 items preprocessed
# 162000 items preprocessed
# 163000 items preprocessed
# 164000 items preprocessed
# 165000 items preprocessed
# 166000 items preprocessed
# 167000 items preprocessed
# 168000 items preprocessed
# 169000 items preprocessed
# 170000 items preprocessed
# 171000 items preprocessed
# 172000 items preprocessed
# 173000 items preprocessed
# 174000 items preprocessed
# 175000 items preprocessed
# 176000 items preprocessed
# 177000 items preprocessed
# 178000 items preprocessed
# 179000 items preprocessed
# 180000 items preprocessed
# 181000 items preprocessed
# 182000 items preprocessed
# 183000 items preprocessed
# 184000 items preprocessed
# 185000 items preprocessed
# 186000 items preprocessed
# 187000 items preprocessed
# 188000 items preprocessed
# 189000 items preprocessed
# 190000 items preprocessed
# 191000 items preprocessed
# 192000 items preprocessed
# 193000 items preprocessed
# 194000 items preprocessed
# 195000 items preprocessed
# 196000 items preprocessed
# 197000 items preprocessed
# 198000 items preprocessed
# 199000 items preprocessed
# 200000 items preprocessed
# 201000 items preprocessed
# 202000 items preprocessed
# 203000 items preprocessed
# 204000 items preprocessed
# 205000 items preprocessed
# 206000 items preprocessed
# 207000 items preprocessed
# 208000 items preprocessed
# 209000 items preprocessed
# 210000 items preprocessed
# 211000 items preprocessed
# 212000 items preprocessed
# 213000 items preprocessed
# 214000 items preprocessed
# 215000 items preprocessed
# 216000 items preprocessed
# 217000 items preprocessed
# 218000 items preprocessed
# 219000 items preprocessed
# 220000 items preprocessed
# 221000 items preprocessed
# 222000 items preprocessed
# 223000 items preprocessed
# 224000 items preprocessed
# 225000 items preprocessed
# 226000 items preprocessed
# 227000 items preprocessed
# 228000 items preprocessed
# 229000 items preprocessed
# 230000 items preprocessed
# 231000 items preprocessed
# 232000 items preprocessed
# 233000 items preprocessed
# 234000 items preprocessed
# 235000 items preprocessed
# 236000 items preprocessed
# 237000 items preprocessed
# 238000 items preprocessed
# 239000 items preprocessed
# 240000 items preprocessed
# 241000 items preprocessed
# 242000 items preprocessed
# 243000 items preprocessed
# 244000 items preprocessed
# 245000 items preprocessed
# 246000 items preprocessed
# 247000 items preprocessed
# 248000 items preprocessed
# 249000 items preprocessed
# 250000 items preprocessed
# 251000 items preprocessed
# 252000 items preprocessed
# 253000 items preprocessed
# 254000 items preprocessed
# 255000 items preprocessed
# 256000 items preprocessed
# 257000 items preprocessed
# 258000 items preprocessed
# 259000 items preprocessed
# 260000 items preprocessed
# 261000 items preprocessed
# 262000 items preprocessed
# 263000 items preprocessed
# 264000 items preprocessed
# 265000 items preprocessed
# 266000 items preprocessed
# 267000 items preprocessed
# 268000 items preprocessed
# 269000 items preprocessed
# 270000 items preprocessed
# 271000 items preprocessed
# 272000 items preprocessed
# 273000 items preprocessed
# 274000 items preprocessed
# 275000 items preprocessed
# 276000 items preprocessed
# 277000 items preprocessed
# 278000 items preprocessed
# 279000 items preprocessed
# 280000 items preprocessed
# 281000 items preprocessed
# 282000 items preprocessed
# 283000 items preprocessed
# 284000 items preprocessed
# 285000 items preprocessed
# 286000 items preprocessed
# 287000 items preprocessed
# 288000 items preprocessed
# 289000 items preprocessed
# 290000 items preprocessed
# 291000 items preprocessed
# 292000 items preprocessed
# 293000 items preprocessed
# 294000 items preprocessed
# 295000 items preprocessed
# 296000 items preprocessed
# 297000 items preprocessed
# 298000 items preprocessed
# 299000 items preprocessed
# 300000 items preprocessed
# 301000 items preprocessed
# 302000 items preprocessed
# 303000 items preprocessed
# 304000 items preprocessed
# 305000 items preprocessed
# 306000 items preprocessed
# 307000 items preprocessed
# 308000 items preprocessed
# 309000 items preprocessed
# 310000 items preprocessed
# 311000 items preprocessed
# 312000 items preprocessed
# 313000 items preprocessed
# 314000 items preprocessed
# 315000 items preprocessed
# 316000 items preprocessed
# 317000 items preprocessed
# 318000 items preprocessed
# 319000 items preprocessed
# 320000 items preprocessed
# 321000 items preprocessed
# 322000 items preprocessed
# 323000 items preprocessed
# 324000 items preprocessed
# 325000 items preprocessed
# 326000 items preprocessed
# 327000 items preprocessed
# 328000 items preprocessed
# 329000 items preprocessed
# 330000 items preprocessed
# 331000 items preprocessed
# 332000 items preprocessed
# 333000 items preprocessed
# 334000 items preprocessed
# 335000 items preprocessed
# 336000 items preprocessed
# 337000 items preprocessed
# 338000 items preprocessed
# 339000 items preprocessed
# 340000 items preprocessed
# 341000 items preprocessed
# 342000 items preprocessed
# 343000 items preprocessed
# 344000 items preprocessed
# 345000 items preprocessed
# 346000 items preprocessed
# 347000 items preprocessed
# 348000 items preprocessed
# 349000 items preprocessed
# 350000 items preprocessed
# 351000 items preprocessed
# 352000 items preprocessed
# 353000 items preprocessed
# 354000 items preprocessed
# 355000 items preprocessed
# 356000 items preprocessed
# 357000 items preprocessed
# 358000 items preprocessed
# 359000 items preprocessed
# 360000 items preprocessed
# 361000 items preprocessed
# 362000 items preprocessed
# 363000 items preprocessed
# 364000 items preprocessed
# 365000 items preprocessed
# 366000 items preprocessed
# 367000 items preprocessed
# 368000 items preprocessed
# 369000 items preprocessed
# 370000 items preprocessed
# 371000 items preprocessed
# 372000 items preprocessed
# 373000 items preprocessed
# 374000 items preprocessed
# 375000 items preprocessed
# 376000 items preprocessed
# 377000 items preprocessed
# 378000 items preprocessed
# 379000 items preprocessed
# 380000 items preprocessed
# 381000 items preprocessed
# 382000 items preprocessed
# 383000 items preprocessed
# 384000 items preprocessed
# 385000 items preprocessed
# 386000 items preprocessed
# 387000 items preprocessed
# 388000 items preprocessed
# 389000 items preprocessed
# 390000 items preprocessed
# 391000 items preprocessed
# 392000 items preprocessed
# 393000 items preprocessed
# 394000 items preprocessed
# 395000 items preprocessed
# 396000 items preprocessed
# 397000 items preprocessed
# 398000 items preprocessed
# 399000 items preprocessed
# 400000 items preprocessed
# 401000 items preprocessed
# 402000 items preprocessed
# 403000 items preprocessed
# 404000 items preprocessed
# 405000 items preprocessed
# 406000 items preprocessed
# 407000 items preprocessed
# 408000 items preprocessed
# 409000 items preprocessed
# 410000 items preprocessed
# 411000 items preprocessed
# 412000 items preprocessed
# 413000 items preprocessed
# 414000 items preprocessed
# 415000 items preprocessed
# 416000 items preprocessed
# 417000 items preprocessed
# 418000 items preprocessed
# 419000 items preprocessed
# 420000 items preprocessed
# 421000 items preprocessed
# 422000 items preprocessed
# 423000 items preprocessed
# 424000 items preprocessed
# 425000 items preprocessed
# 426000 items preprocessed
# 427000 items preprocessed
# 428000 items preprocessed
# 429000 items preprocessed
# 430000 items preprocessed
# 431000 items preprocessed
# 432000 items preprocessed
# 433000 items preprocessed
# 434000 items preprocessed
# 435000 items preprocessed
# 436000 items preprocessed
# 437000 items preprocessed
# 438000 items preprocessed
# 439000 items preprocessed
# 440000 items preprocessed
# 441000 items preprocessed
# 442000 items preprocessed
# 443000 items preprocessed
# 444000 items preprocessed
# 445000 items preprocessed
# 446000 items preprocessed
# 447000 items preprocessed
# 448000 items preprocessed
# 449000 items preprocessed
# 450000 items preprocessed
# 451000 items preprocessed
# 452000 items preprocessed
# 453000 items preprocessed
# 454000 items preprocessed
# 455000 items preprocessed
# 456000 items preprocessed
# 457000 items preprocessed
# 458000 items preprocessed
# 459000 items preprocessed
# 460000 items preprocessed
# 461000 items preprocessed
# 462000 items preprocessed
# 463000 items preprocessed
# 464000 items preprocessed
# 465000 items preprocessed
# 466000 items preprocessed
# 467000 items preprocessed
# 468000 items preprocessed
# 469000 items preprocessed
# 470000 items preprocessed
# 471000 items preprocessed
# 472000 items preprocessed
# 473000 items preprocessed
# 474000 items preprocessed
# 475000 items preprocessed
# 476000 items preprocessed
# 477000 items preprocessed
# 478000 items preprocessed
# 479000 items preprocessed
# 480000 items preprocessed
# 481000 items preprocessed
# 482000 items preprocessed
# 483000 items preprocessed
# 484000 items preprocessed
# 485000 items preprocessed
# 486000 items preprocessed
# 487000 items preprocessed
# 488000 items preprocessed
# 489000 items preprocessed
# 490000 items preprocessed
# 491000 items preprocessed
# 492000 items preprocessed
# 493000 items preprocessed
# 494000 items preprocessed
# 495000 items preprocessed
# 496000 items preprocessed
# 497000 items preprocessed
# 498000 items preprocessed
# 499000 items preprocessed
# 500000 items preprocessed
# 501000 items preprocessed
# 502000 items preprocessed
# 503000 items preprocessed
# 504000 items preprocessed
# 505000 items preprocessed
# 506000 items preprocessed
# 507000 items preprocessed
# 508000 items preprocessed
# 509000 items preprocessed
# 510000 items preprocessed
# 511000 items preprocessed
# 512000 items preprocessed
# 513000 items preprocessed
# 514000 items preprocessed
# 515000 items preprocessed
# 516000 items preprocessed
# 517000 items preprocessed
# 518000 items preprocessed
# 519000 items preprocessed
# 520000 items preprocessed
# 521000 items preprocessed
# 522000 items preprocessed
# 523000 items preprocessed
# 524000 items preprocessed
# 525000 items preprocessed
# 526000 items preprocessed
# 527000 items preprocessed
# 528000 items preprocessed
# 529000 items preprocessed
# 530000 items preprocessed
# 531000 items preprocessed
# 532000 items preprocessed
# 533000 items preprocessed
# 534000 items preprocessed
# 535000 items preprocessed
# 536000 items preprocessed
# 537000 items preprocessed
# 538000 items preprocessed
# 539000 items preprocessed
# 540000 items preprocessed
# 541000 items preprocessed
# 542000 items preprocessed
# 543000 items preprocessed
# 544000 items preprocessed
# 545000 items preprocessed
# 546000 items preprocessed
# 547000 items preprocessed
# 548000 items preprocessed
# 549000 items preprocessed
# 550000 items preprocessed
# 551000 items preprocessed
# 552000 items preprocessed
# 553000 items preprocessed
# 554000 items preprocessed
# 555000 items preprocessed
# 556000 items preprocessed
# 557000 items preprocessed
# 558000 items preprocessed
# 559000 items preprocessed
# 560000 items preprocessed
# 561000 items preprocessed
# 562000 items preprocessed
# 563000 items preprocessed
# 564000 items preprocessed
# 565000 items preprocessed
# 566000 items preprocessed
# 567000 items preprocessed
# 568000 items preprocessed
# 569000 items preprocessed
# 570000 items preprocessed
# 571000 items preprocessed
# 572000 items preprocessed
# 573000 items preprocessed
# 574000 items preprocessed
# 575000 items preprocessed
# 576000 items preprocessed
# 577000 items preprocessed
# 578000 items preprocessed
# 579000 items preprocessed
# 580000 items preprocessed
# 581000 items preprocessed
# 582000 items preprocessed
# 583000 items preprocessed
# 584000 items preprocessed
# 585000 items preprocessed
# 586000 items preprocessed
# 587000 items preprocessed
# 588000 items preprocessed
# 589000 items preprocessed
# 590000 items preprocessed
# 591000 items preprocessed
# 592000 items preprocessed
# 593000 items preprocessed
# 594000 items preprocessed
# 595000 items preprocessed
# 596000 items preprocessed
# 597000 items preprocessed
# 598000 items preprocessed
# 599000 items preprocessed
# 600000 items preprocessed
# 601000 items preprocessed
# 602000 items preprocessed
# 603000 items preprocessed
# 604000 items preprocessed
# 605000 items preprocessed
# 606000 items preprocessed
# 607000 items preprocessed
# 608000 items preprocessed
# 609000 items preprocessed
# 610000 items preprocessed
# 611000 items preprocessed
# 612000 items preprocessed
# 613000 items preprocessed
# 614000 items preprocessed
# 615000 items preprocessed
# 616000 items preprocessed
# 617000 items preprocessed
# 618000 items preprocessed
# 619000 items preprocessed
# 620000 items preprocessed
# 621000 items preprocessed
# 622000 items preprocessed
# 623000 items preprocessed
# 624000 items preprocessed
# 625000 items preprocessed
# 626000 items preprocessed
# 627000 items preprocessed
# 628000 items preprocessed
# 629000 items preprocessed
# 630000 items preprocessed
# 631000 items preprocessed
# 632000 items preprocessed
# 633000 items preprocessed
# 634000 items preprocessed
# 635000 items preprocessed
# 636000 items preprocessed
# 637000 items preprocessed
# 638000 items preprocessed
# 639000 items preprocessed
# 640000 items preprocessed
# 641000 items preprocessed
# 642000 items preprocessed
# 643000 items preprocessed
# 644000 items preprocessed
# 645000 items preprocessed
# 646000 items preprocessed
# 647000 items preprocessed
# 648000 items preprocessed
# 649000 items preprocessed
# 650000 items preprocessed
# 651000 items preprocessed
# 652000 items preprocessed
# 653000 items preprocessed
# 654000 items preprocessed
# 655000 items preprocessed
# 656000 items preprocessed
# 657000 items preprocessed
# 658000 items preprocessed
# 659000 items preprocessed
# 660000 items preprocessed
# 661000 items preprocessed
# 662000 items preprocessed
# 663000 items preprocessed
# 664000 items preprocessed
# 665000 items preprocessed
# 666000 items preprocessed
# 667000 items preprocessed
# 668000 items preprocessed
# 669000 items preprocessed
# 670000 items preprocessed
# 671000 items preprocessed
# 672000 items preprocessed
# 673000 items preprocessed
# 674000 items preprocessed
# 675000 items preprocessed
# 676000 items preprocessed
# 677000 items preprocessed
# 678000 items preprocessed
# 679000 items preprocessed
# 680000 items preprocessed
# 681000 items preprocessed
# 682000 items preprocessed
# 683000 items preprocessed
# 684000 items preprocessed
# 685000 items preprocessed
# 686000 items preprocessed
# 687000 items preprocessed
# 688000 items preprocessed
# 689000 items preprocessed
# 690000 items preprocessed
# 691000 items preprocessed
# 692000 items preprocessed
# 693000 items preprocessed
# 694000 items preprocessed
# 695000 items preprocessed
# 696000 items preprocessed
# 697000 items preprocessed
# 698000 items preprocessed
# 699000 items preprocessed
# 700000 items preprocessed
# 701000 items preprocessed
# 702000 items preprocessed
# 703000 items preprocessed
# 704000 items preprocessed
# 705000 items preprocessed
# 706000 items preprocessed
# 707000 items preprocessed
# 708000 items preprocessed
# 709000 items preprocessed
# 710000 items preprocessed
# 711000 items preprocessed
# 712000 items preprocessed
# 713000 items preprocessed
# 714000 items preprocessed
# 715000 items preprocessed
# 716000 items preprocessed
# 717000 items preprocessed
# 718000 items preprocessed
# 719000 items preprocessed
# 720000 items preprocessed
# 721000 items preprocessed
# 722000 items preprocessed
# 723000 items preprocessed
# 724000 items preprocessed
# 725000 items preprocessed
# 726000 items preprocessed
# 727000 items preprocessed
# 728000 items preprocessed
# 729000 items preprocessed
# 730000 items preprocessed
# 731000 items preprocessed
# 732000 items preprocessed
# 733000 items preprocessed
# 734000 items preprocessed
# 735000 items preprocessed
# 736000 items preprocessed
# 737000 items preprocessed
# 738000 items preprocessed
# 739000 items preprocessed
# 740000 items preprocessed
# 741000 items preprocessed
# 742000 items preprocessed
# 743000 items preprocessed
# 744000 items preprocessed
# 745000 items preprocessed
# 746000 items preprocessed
# 747000 items preprocessed
# 748000 items preprocessed
# 749000 items preprocessed
# 750000 items preprocessed
# 751000 items preprocessed
# 752000 items preprocessed
# 753000 items preprocessed
# 754000 items preprocessed
# 755000 items preprocessed
# 756000 items preprocessed
# 757000 items preprocessed
# 758000 items preprocessed
# 759000 items preprocessed
# 760000 items preprocessed
# 761000 items preprocessed
# 762000 items preprocessed
# 763000 items preprocessed
# 764000 items preprocessed
# 765000 items preprocessed
# 766000 items preprocessed
# 767000 items preprocessed
# 768000 items preprocessed
# 769000 items preprocessed
# 770000 items preprocessed
# 771000 items preprocessed
# 772000 items preprocessed
# 773000 items preprocessed
# 774000 items preprocessed
# 775000 items preprocessed
# 776000 items preprocessed
# 777000 items preprocessed
# 778000 items preprocessed
# 779000 items preprocessed
# 780000 items preprocessed
# 781000 items preprocessed
# 782000 items preprocessed
# 783000 items preprocessed
# 784000 items preprocessed
# 785000 items preprocessed
# 786000 items preprocessed
# 787000 items preprocessed
# 788000 items preprocessed
# 789000 items preprocessed
# 790000 items preprocessed
# 791000 items preprocessed
# 792000 items preprocessed
# 793000 items preprocessed
# 794000 items preprocessed
# 795000 items preprocessed
# 796000 items preprocessed
# 797000 items preprocessed
# 798000 items preprocessed
# 799000 items preprocessed
# 800000 items preprocessed
# 801000 items preprocessed
# 802000 items preprocessed
# 803000 items preprocessed
# 804000 items preprocessed
# 805000 items preprocessed
# 806000 items preprocessed
# 807000 items preprocessed
# 808000 items preprocessed
# 809000 items preprocessed
# 810000 items preprocessed
# 811000 items preprocessed
# 812000 items preprocessed
# 813000 items preprocessed
# 814000 items preprocessed
# 815000 items preprocessed
# 816000 items preprocessed
# 817000 items preprocessed
# 818000 items preprocessed
# 819000 items preprocessed
# 820000 items preprocessed
# 821000 items preprocessed
# 822000 items preprocessed
# 823000 items preprocessed
# 824000 items preprocessed
# 825000 items preprocessed
# 826000 items preprocessed
# 827000 items preprocessed
# 828000 items preprocessed
# 829000 items preprocessed
# 830000 items preprocessed
# 831000 items preprocessed
# 832000 items preprocessed
# 833000 items preprocessed
# 834000 items preprocessed
# 835000 items preprocessed
# 836000 items preprocessed
# 837000 items preprocessed
# 838000 items preprocessed
# 839000 items preprocessed
# 840000 items preprocessed
# 841000 items preprocessed
# 842000 items preprocessed
# 843000 items preprocessed
# 844000 items preprocessed
# 845000 items preprocessed
# 846000 items preprocessed
# 847000 items preprocessed
# 848000 items preprocessed
# 849000 items preprocessed
# 850000 items preprocessed
# 851000 items preprocessed
# 852000 items preprocessed
# 853000 items preprocessed
# 854000 items preprocessed
# 855000 items preprocessed
# 856000 items preprocessed
# 857000 items preprocessed
# 858000 items preprocessed
# 859000 items preprocessed
# 860000 items preprocessed
# 861000 items preprocessed
# 862000 items preprocessed
# 863000 items preprocessed
# 864000 items preprocessed
# 865000 items preprocessed
# 866000 items preprocessed
# 867000 items preprocessed
# 868000 items preprocessed
# 869000 items preprocessed
# 870000 items preprocessed
# 871000 items preprocessed
# 872000 items preprocessed
# 873000 items preprocessed
# 874000 items preprocessed
# 875000 items preprocessed
# 876000 items preprocessed
# 877000 items preprocessed
# 878000 items preprocessed
# 879000 items preprocessed
# 880000 items preprocessed
# 881000 items preprocessed
# 882000 items preprocessed
# 883000 items preprocessed
# 884000 items preprocessed
# 885000 items preprocessed
# 886000 items preprocessed
# 887000 items preprocessed
# 888000 items preprocessed
# 889000 items preprocessed
# 890000 items preprocessed
# 891000 items preprocessed
# 892000 items preprocessed
# 893000 items preprocessed
# 894000 items preprocessed
# 895000 items preprocessed
# 896000 items preprocessed
# 897000 items preprocessed
# 898000 items preprocessed
# 899000 items preprocessed
# 900000 items preprocessed
# 901000 items preprocessed
# 902000 items preprocessed
# 903000 items preprocessed
# 904000 items preprocessed
# 905000 items preprocessed
# 906000 items preprocessed
# 907000 items preprocessed
# 908000 items preprocessed
# 909000 items preprocessed
# 910000 items preprocessed
# 911000 items preprocessed
# 912000 items preprocessed
# 913000 items preprocessed
# 914000 items preprocessed
# 915000 items preprocessed
# 916000 items preprocessed
# 917000 items preprocessed
# 918000 items preprocessed
# 919000 items preprocessed
# 920000 items preprocessed
# 921000 items preprocessed
# 922000 items preprocessed
# 923000 items preprocessed
# 924000 items preprocessed
# 925000 items preprocessed
# 926000 items preprocessed
# 927000 items preprocessed
# 928000 items preprocessed
# 929000 items preprocessed
# 930000 items preprocessed
# 931000 items preprocessed
# 932000 items preprocessed
# 933000 items preprocessed
# 934000 items preprocessed
# 935000 items preprocessed
# 936000 items preprocessed
# 937000 items preprocessed
# 938000 items preprocessed
# 939000 items preprocessed
# 940000 items preprocessed
# 941000 items preprocessed
# 942000 items preprocessed
# 943000 items preprocessed
# 944000 items preprocessed
# 945000 items preprocessed
# 946000 items preprocessed
# 947000 items preprocessed
# 948000 items preprocessed
# 949000 items preprocessed
# 950000 items preprocessed
# 951000 items preprocessed
# 952000 items preprocessed
# 953000 items preprocessed
# 954000 items preprocessed
# 955000 items preprocessed
# 956000 items preprocessed
# 957000 items preprocessed
# 958000 items preprocessed
# 959000 items preprocessed
# 960000 items preprocessed
# 961000 items preprocessed
# 962000 items preprocessed
# 963000 items preprocessed
# 964000 items preprocessed
# 965000 items preprocessed
# 966000 items preprocessed
# 967000 items preprocessed
# 968000 items preprocessed
# 969000 items preprocessed
# 970000 items preprocessed
# 971000 items preprocessed
# 972000 items preprocessed
# 973000 items preprocessed
# 974000 items preprocessed
# 975000 items preprocessed
# 976000 items preprocessed
# 977000 items preprocessed
# 978000 items preprocessed
# 979000 items preprocessed
# 980000 items preprocessed
# 981000 items preprocessed
# 982000 items preprocessed
# 983000 items preprocessed
# 984000 items preprocessed
# 985000 items preprocessed
# 986000 items preprocessed
# 987000 items preprocessed
# 988000 items preprocessed
# 989000 items preprocessed
# 990000 items preprocessed
# 991000 items preprocessed
# 992000 items preprocessed
# 993000 items preprocessed
# 994000 items preprocessed
# 995000 items preprocessed
# 996000 items preprocessed
