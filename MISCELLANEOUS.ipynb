# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('C:/Users/Froilan/Desktop/myFiles/JupyterFiles/stock_correlation_prediction/train_dev_test/before_arima/train.csv')
data = np.transpose(data.loc[:,~data.columns.str.contains("^Unnamed")])
print(data.head())
# Out:
#       0         1         2         3         4         5         6      \
# 0  0.646860  0.518209  0.265099 -0.464590 -0.667206 -0.356145 -0.202976
# 1  0.129343  0.757073  0.902180  0.851546  0.648949 -0.006025  0.775013
# 2  0.076145 -0.301920 -0.516127 -0.536545 -0.300962  0.565409  0.267997
# 3  0.380201  0.729120  0.761980  0.802278  0.546734  0.304397  0.753708
# 4  0.304520  0.594037  0.346457  0.220923  0.116298  0.334984  0.617741
#
#       7         8         9        ...        55865     55866     55867  \
# 0 -0.693420 -0.843329 -0.826591    ...     0.396239  0.627391  0.850063
# 1  0.898395  0.842937  0.660141    ...     0.870828  0.854808  0.820514
# 2 -0.065908 -0.478655 -0.293153    ...     0.705180  0.650549  0.870403
# 3  0.696901  0.716963  0.610864    ...     0.110969  0.063280  0.520852
# 4  0.561720  0.750150  0.678119    ...     0.117950 -0.584284 -0.566581
#
#       55868     55869     55870     55871     55872     55873     55874
# 0  0.890753  0.876121 -0.098180 -0.368111 -0.167918  0.242583  0.802539
# 1  0.757564  0.754556  0.917817  0.937390  0.945463  0.937526  0.833362
# 2  0.854353  0.821601  0.071451  0.008614  0.243556  0.563173  0.684904
# 3  0.762691  0.806614  0.595682  0.771566  0.921268  0.951715  0.943243
# 4 -0.222365  0.713997  0.844499  0.850320  0.632534  0.386957  0.413954
#
# [5 rows x 55875 columns]

# %%
data[0].plot()
plt.xlabel('time step')
plt.ylabel('correlation coefficient')
plt.show()
plt.close()
